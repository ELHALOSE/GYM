# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 901.3/901.3 kB 27.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **Count object**

# %%
# import cv2
# import numpy as np
# from ultralytics import solutions


# def count_objects_in_region(video_path, output_video_path, model_path):
#     """Count objects in a specific region within a video."""
#     cap = cv2.VideoCapture(video_path)
#     assert cap.isOpened(), "Error reading video file"
#     w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
#     video_writer = cv2.VideoWriter(output_video_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

#     region_points = [(10, 130), (1080, 130), (1080, 100), (10, 100)]
#     counter = solutions.ObjectCounter(show=True, region=region_points, model=model_path)

#     while cap.isOpened():
#         success, im0 = cap.read()
#         if not success:
#             print("Video frame is empty or video processing has been successfully completed.")
#             break
#         im0 = counter.count(im0)
#         video_writer.write(im0)

#     cap.release()
#     video_writer.release()
#     cv2.destroyAllWindows()


# count_objects_in_region("/content/background video ｜ people ｜ walking ｜.mp4", "output_video.avi", "yolo11n.pt")

# %%
# import cv2
# import numpy as np
# from ultralytics import solutions


# def count_objects_in_region(video_path, output_video_path, model_path):
#     """Count objects in a specific region within a video."""
#     cap = cv2.VideoCapture(video_path)
#     assert cap.isOpened(), "Error reading video file"
#     w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
#     video_writer = cv2.VideoWriter(output_video_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

#     region_points = [(120, 300), (580, 300), (580, 250), (120, 250)]
#     counter = solutions.ObjectCounter(show=True, region=region_points, model=model_path)

#     while cap.isOpened():
#         success, im0 = cap.read()
#         if not success:
#             print("Video frame is empty or video processing has been successfully completed.")
#             break
#         im0 = counter.count(im0)
#         video_writer.write(im0)

#     cap.release()
#     video_writer.release()
#     cv2.destroyAllWindows()


# count_objects_in_region("/content/Traffic IP Camera video.mp4", "output_video.avi", "yolo11n.pt")
# Out:
# Ultralytics Solutions: ✅ {'region': [(120, 300), (580, 300), (580, 250), (120, 250)], 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'records': 5, 'show': True, 'model': 'yolo11n.pt'}
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# 0: 384x640 2 cars, 236.5ms
# Speed: 2.2ms preprocess, 236.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 207.1ms
# Speed: 2.6ms preprocess, 207.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 133.8ms
# Speed: 2.3ms preprocess, 133.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 128.8ms
# Speed: 5.8ms preprocess, 128.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 129.5ms
# ...

# %% [markdown]
# # **GYM Motion**

# %%
import cv2

from ultralytics import solutions

cap = cv2.VideoCapture("/content/💪🏽 6 PUSH UP VARIATIONS TO BUILD A STRONGER CHEST, TRICEPS, SHOULDERS & BACK 🔥.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Video writer
video_writer = cv2.VideoWriter("workouts.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Init AIGym
gym = solutions.AIGym(
    show=True,  # Display the frame
    kpts=[6, 8, 10],  # keypoints index of person for monitoring specific exercise, by default it's for pushup
    model="yolo11n-pose.pt",  # Path to the YOLO11 pose estimation model file
    # line_width=2,  # Adjust the line width for bounding boxes and text display
)

# Process video
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    im0 = gym.monitor(im0)
    video_writer.write(im0)

cv2.destroyAllWindows()
video_writer.release()
# Out:
# Ultralytics Solutions: ✅ {'region': [(20, 400), (1080, 400), (1080, 360), (20, 360)], 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'records': 5, 'show': True, 'model': 'yolo11n-pose.pt'}
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# 0: 640x384 1 person, 304.0ms
# Speed: 2.2ms preprocess, 304.0ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 369.8ms
# Speed: 8.0ms preprocess, 369.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 266.6ms
# Speed: 2.1ms preprocess, 266.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.2ms
# Speed: 4.2ms preprocess, 169.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 175.5ms
# ...
